# %% [markdown]
# <img src="https://user-images.githubusercontent.com/7065401/39117599-a2ca6a88-46e7-11e8-9eb1-e3321aec3f49.png"
#     style="width:300px; float: right; margin: 0 40px 40px 40px;"></img>

# %% [markdown]
# # Visualizaciones

# %% [markdown]
# ## Matplotlib

# %% [markdown]
# Matplotlib es una de las bibliotecas más populares en Python para la creación de gráficos y visualizaciones de datos. Fundada en 2003 por John D. Hunter, proporciona herramientas robustas para generar gráficos bidimensionales de alta calidad. Es fundamental para cualquiera que trabaje con datos en Python, siendo la base sobre la cual se han construido otras bibliotecas como Seaborn y Plotly.

# %% [markdown]
# Matplotlib se destaca por su simplicidad y flexibilidad. Aunque existen otras bibliotecas para la visualización de datos, Matplotlib sigue siendo la más utilizada gracias a su capacidad para generar gráficos altamente personalizables. Además, al ser de código abierto, es accesible y ampliamente utilizada por la comunidad científica y de desarrollo.

# %%
import numpy as np
import pandas as pd

# %%
# importar las libreria
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Dos formas principales de uso

# %% [markdown]
# #### Modo API

# %%
x = np.arange(-10, 11)

# %%
# metodo plt
plt.figure(figsize=(12, 6))

plt.title('Mi primer grafico')

plt.plot(x, x ** 2)
plt.plot(x, -1 * (x ** 2))

# %%
plt.figure(figsize=(12, 6))
plt.title('Mi segundo grafico')

plt.subplot(1, 2, 1)  # fila, columna, panel seleccionado
plt.plot(x, x ** 2)
plt.plot([0, 0, 0], [-10, 0, 100])
plt.legend(['X^2', 'Linea vertical'])
plt.xlabel('X')
plt.ylabel('X al cuadrado')

plt.subplot(1, 2, 2)     # fila columna panel
plt.plot(x, -1 * (x ** 2))
plt.plot([-10, 0, 10], [-50, -50, -50])
plt.legend(['-X^2', 'Linea Horizontal'])
plt.xlabel('X')
plt.ylabel('-X Squared')


plt.xlabel('X')
plt.ylabel('X al cuadrado')
# Out:
# Text(0, 0.5, 'X al cuadrado')

# %% [markdown]
# #### Modo OOP (API orientada a objetos)

# %%
fig, axes = plt.subplots(figsize=(12, 6))

# %%
axes.plot(
    x, (x ** 2), color='red', linewidth=3,
    marker='o', markersize=8, label='X^2')

axes.plot(x, -1 * (x ** 2), 'b--', label='-X^2')

axes.set_xlabel('X')
axes.set_ylabel('X al 2')

axes.set_title("Mi primer OOP grafico")

axes.legend()

fig

# %% [markdown]
# ### Tipos de *Graficos*

# %% [markdown]
# #### Grafico de lineas

# %%
# Datos de ejemplo --- poblacion Pais / años
df = pd.DataFrame({"Year": [1920, 1930, 1940, 1950, 1960, 1970, 1980, 1990, 2000, 2010],
                   "Population1": [2.51, 2.65, 2.79, 2.92, 3.00, 3.08, 3.09, 3.12, 3.20, 3.25]})

# %%
df
# Out:
#    Year  Population1
# 0  1920         2.51
# 1  1930         2.65
# 2  1940         2.79
# 3  1950         2.92
# 4  1960         3.00
# 5  1970         3.08
# 6  1980         3.09
# 7  1990         3.12
# 8  2000         3.20
# 9  2010         3.25

# %%
plt.plot(df["Year"], df["Population1"])
plt.show()

# %%
# marker linestyle color
plt.plot(df["Year"], df["Population1"], marker='o', linestyle="--", color="green")
# titulo
plt.title("Grafico de lineas - Evolucion de la poblacion de un pais")
# xlabel
plt.xlabel("Años")
# y label
plt.ylabel("Poblacion")
plt.show()

# %%
plt.plot(df["Year"], df["Population1"], marker='o', linestyle="--", color="green")
plt.title("Grafico de lineas - Evolucion de la poblacion de un pais")
plt.xlabel("Años")
plt.ylabel("Poblacion")
# grid y los labels en y
plt.grid(True)
plt.yticks([2.5, 3.0, 3.4], ["2.5 Bajo", "Medio", "Alto"])
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(df["Year"], df["Population1"], marker='o', linestyle="--", color="green")
plt.title("Grafico de lineas - Evolucion de la poblacion de un pais")
plt.xlabel("Años")
plt.ylabel("Poblacion")
plt.grid(True)
plt.yticks([2.5, 3.0, 3.4], ["2.5 Bajo", "Medio", "Alto"])

# le agregamos el valor a cada puntos
for indice, valor in enumerate(df["Population1"]):
    plt.text(df["Year"][indice], df["Population1"][indice], valor, fontsize=12, ha="right", va="bottom", color="black")

plt.show()

# %%
# Datos de ejemplo --- poblacion Pais / años
df2 = pd.DataFrame({"Year": [1920, 1930, 1940, 1950, 1960, 1970, 1980, 1990, 2000, 2010],
                   "Population1": [3.51, 6.65, 9.79, 2.92, 8.00, 10.08, 13.09, 13.12, 13.20, 13.25]})

# %%
plt.figure(figsize=(10, 6))
plt.plot(df["Year"], df["Population1"], marker='o', linestyle="--", color="green", label="pais 1")
plt.plot(df2["Year"], df2["Population1"], marker='x', linestyle="--", color="red", label= "pais 2")
plt.title("Grafico de lineas - Evolucion de la poblacion de un pais")
plt.xlabel("Años")
plt.ylabel("Poblacion")
plt.grid(True)
plt.yticks([2.5, 3.0, 3.4], ["2.5 Bajo", "3. 0 Medio", "3.4 Alto"])
plt.legend(loc='right')
plt.show()

# %% [markdown]
# Guardar el grafico en un archivo

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
plt.figure(figsize=(10, 6))
plt.plot(df["Year"], df["Population1"], marker='o', linestyle="--", color="green", label="pais 1")
plt.plot(df2["Year"], df2["Population1"], marker='x', linestyle="--", color="red", label= "pais 2")
plt.title("Grafico de lineas - Evolucion de la poblacion de un pais")
plt.xlabel("Años")
plt.ylabel("Poblacion")
plt.grid(True)
plt.yticks([2.5, 3.0, 3.4], ["2.5 Bajo", "Medio", "Alto"])
plt.legend(loc='right')
plt.savefig("/content/drive/MyDrive/samples/grafico.jpg")
plt.show()

# %% [markdown]
# Vamos a ver los subplots

# %%
df_lluvias = pd.read_csv('/content/drive/MyDrive/samples/lluvias.csv')

# %%
df_lluvias.head()
# Out:
#    Year    Jan    Feb    Mar     Apr     May      Jun      Jul      Aug  \
# 0  1965  0.029  0.069  0.000  21.667  17.859  102.111  606.071  402.521
# 1  1966  0.905  0.000  0.000   2.981  63.008   94.088  481.942   59.386
# 2  1967  0.248  3.390  1.320  13.482  11.116  251.314  780.006  181.069
# 3  1968  0.318  3.035  1.704  23.307   7.441  179.872  379.354  171.979
# 4  1969  0.248  2.524  0.334   4.569   6.213  393.682  678.354  397.335
#
#        Sep     Oct     Nov     Dec
# 0   69.511   5.249  16.232  22.075
# 1  150.624   1.308  41.214   4.132
# 2  183.757  50.404   8.393  37.685
# 3  219.884  73.997  23.326   2.020
# 4  205.413  24.014  24.385   1.951

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 5), sharex=True)

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 5), sharex=True, sharey=True)

# Graficar los datos de precipitaciones para cada mes
ax[0].plot(df_lluvias["Year"], df_lluvias['Jan'], label='Precipitaciones de enero')
ax[1].plot(df_lluvias["Year"], df_lluvias['Feb'], label='Precipitaciones de febrero', color='C1')
ax[2].plot(df_lluvias["Year"], df_lluvias['Mar'], label='Precipitaciones de marzo', color='C2')

# Agregar títulos y leyendas
ax[0].set_title('Precipitaciones mensuales')
ax[2].set_xlabel('Año')  # Solo la última tiene etiqueta en el eje X
for a in ax:
    a.legend()  # Agregar la leyenda a cada gráfico
    a.grid(True)  # Agregar una cuadrícula para mejor visualización

# Ajustar los espacios entre los subgráficos
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# Grafico de barras

# %% [markdown]
# Se usan para representar y comparar cantidades en categorías discretas de manera clara y visual. Son especialmente útiles cuando quieren mostrar diferencias entre grupos o analizar tendencias en datos categóricos.

# %%
# generamos dos listas a partir de las cuales generamos el DF a graficar
paises = ['Argentina', 'Bolivia', 'Brasil', 'Chile', 'Colombia', 'Ecuador', 'Paraguay', 'Peru', 'Uruguay', 'Venezuela', "Canada"]
np.random.seed(10)
poblacion = [np.random.randint(10,100)+i for i in range(len(paises))]

# %%
paises
# Out:
# ['Argentina',
#  'Bolivia',
#  'Brasil',
#  'Chile',
#  'Colombia',
#  'Ecuador',
#  'Paraguay',
#  'Peru',
#  'Uruguay',
#  'Venezuela',
#  'Canada']

# %%
poblacion
# Out:
# [19, 26, 76, 41, 103, 44, 24, 90, 18, 59, 56]

# %%
df = pd.DataFrame({'Pais': paises, 'Poblacion': poblacion})

# %%
df.head()
# Out:
#         Pais  Poblacion
# 0  Argentina         19
# 1    Bolivia         26
# 2     Brasil         76
# 3      Chile         41
# 4   Colombia        103

# %%
# con plt.bar hacemos un grafico de barras
plt.bar(df['Pais'], df['Poblacion'])
plt.show()

# %%
# lo agrandamos con figsize en pulgadas
plt.figure(figsize=(10,6))
plt.bar(df['Pais'], df['Poblacion'])
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.bar(df["Pais"], df["Poblacion"], color='red', edgecolor="black", width=0.5)

plt.title('Grafico de barras - Poblacion por pais')

plt.xlabel('Paises', fontsize=12)
plt.ylabel('Poblacion', fontsize=12)

# Agregar cuadrícula horizontal -- alpha transparencia
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Rotar etiquetas del eje X si son largas ha sentido
plt.xticks(rotation=90, ha="right")

# los valores arriba de la barra i index v value
for i, v in enumerate(df["Poblacion"]):
    plt.text(i, v+1, str(v), ha="center", fontsize=10, fontweight="bold")

# %%
# ordenamos los valores de mayor a menor
df = df.sort_values(by="Poblacion", ascending=False)

# %%
plt.figure(figsize=(10,5))

# Descomentar para color rojo
plt.bar(df["Pais"], df["Poblacion"], color='red', edgecolor="black", width=0.5)

# Descomentar para colores random
# colores = np.random.rand(len(df))
# plt.bar(df["Pais"], df["Poblacion"], color=plt.cm.viridis(colores), edgecolor="black", width=0.5)

# Descomentar para pasando una lista de colores
# colores = [
#     "red", "blue", "green", "orange", "purple",
#     "cyan", "magenta", "yellow", "brown", "pink", "gray"
# ]
# plt.bar(df["Pais"], df["Poblacion"], color=colores, edgecolor="black", width=0.5)

plt.title('Grafico de barras - Poblacion por pais')

plt.xlabel('Paises', fontsize=12)
plt.ylabel('Poblacion', fontsize=12)

# Agregar cuadrícula horizontal -- alpha transparencia
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Rotar etiquetas del eje X si son largas ha sentido
plt.xticks(rotation=90, ha="right")

# los valores arriba de la barra i index v value
for indice, valor in enumerate(df["Poblacion"]):
    plt.text(indice, valor+1, str(valor), ha="center", fontsize=10, fontweight="bold")

# %%
# vamos a hacer un grafico de barras con dos categorias
data = {
    "fecha_compra": pd.date_range(start="2024-01-01", periods=12, freq="15D"),
    "mes": ["Ene", "Ene", "Ene", "Feb", "Feb", "Feb", "Mar", "Mar", "Mar", "Abr", "Abr", "Abr"],
    "sexo": ["H", "M", "H", "H", "M", "M", "H", "H", "M", "M", "H", "M"],
    "consumo": [50, 60, 70, 90, 110, 100, 120, 130, 150, 160, 140, 180],
}

# %%
df = pd.DataFrame(data)
df.head()
# Out:
#   fecha_compra  mes sexo  consumo
# 0   2024-01-01  Ene    H       50
# 1   2024-01-16  Ene    M       60
# 2   2024-01-31  Ene    H       70
# 3   2024-02-15  Feb    H       90
# 4   2024-03-01  Feb    M      110

# %%
# Agrupar por mes y sexo sumando los consumos
df_grouped = df.groupby(["mes", "sexo"])["consumo"].sum().unstack()

# %%
# sumo los dos consumos
df_grouped["total"] = df_grouped["H"] + df_grouped["M"]
df_grouped
# Out:
# sexo    H    M  total
# mes
# Abr   140  340    480
# Ene   120   60    180
# Feb    90  210    300
# Mar   250  150    400

# %%
x = np.arange(len(df_grouped.index))
x
# Out:
# array([0, 1, 2, 3])

# %%
# Crear gráfico apilado
# x = np.arange(len(df_grouped.index))  # Posiciones en el eje X

plt.figure(figsize=(8, 5))

plt.bar(df_grouped.index, df_grouped["H"], label="Hombres", color="blue")
plt.bar(df_grouped.index, df_grouped["M"], bottom=df_grouped["H"], label="Mujeres", color="green")  # Se apila sobre Hombres

# Configurar etiquetas y título
plt.xticks(x, df_grouped.index)
plt.xlabel("Mes")
plt.ylabel("Consumo Total")
plt.title("Consumo Mensual por Sexo (Apilado)")
plt.legend()
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Mostrar gráfico
plt.show()

# %% [markdown]
# Gtrafico de Tortas - Pie chart

# %% [markdown]
# Se utilizan para representar proporciones o porcentajes de un todo. Son útiles cuando se quieren mostrar cómo se distribuyen las partes de un conjunto total.

# %%
# Datos de ejemplo -- Unidades de vehiculos vendidas por marca
data = {
    "Fabricante": ["Toyota", "Volkswagen", "Ford", "Honda", "BMW", "Chevrolet"],
    "Unidades": [25000, 20000, 15000, 13000, 12000, 15000]
}

# Crear DataFrame
df = pd.DataFrame(data)
df
# Out:
#    Fabricante  Unidades
# 0      Toyota     25000
# 1  Volkswagen     20000
# 2        Ford     15000
# 3       Honda     13000
# 4         BMW     12000
# 5   Chevrolet     15000

# %%
plt.pie(df["Unidades"], labels=df["Fabricante"], autopct="%1.1f%%")
plt.show()

# %%
plt.figure(figsize=(8, 8))
plt.pie(
    df['Unidades'],
    labels=df["Fabricante"],
    autopct='%1.1f%%',   # Muestra los porcentajes con 1 decimal
    startangle=140,      # Ángulo inicial para mejorar la distribución
    wedgeprops={'edgecolor': 'black', 'linewidth': 1},  # Bordes negros para mejor visibilidad
    textprops={'fontsize': 10}  # Tamaño del texto
)

# Agregar título
plt.title("Participacion de mercado de marcas de autos", fontsize=14, fontweight="bold")

plt.show()

# %%
# Datos simulados
data = {
    "Marca": ["Toyota", "Volkswagen", "Ford", "Honda", "BMW", "Chevrolet"],
    "Ventas": [25000, 20000, 15000, 13000, 12000, 15000]
}
df = pd.DataFrame(data)

# Ordenar de mayor a menor
df = df.sort_values(by="Ventas", ascending=False)

# Extraer datos ordenados
marcas = df["Marca"]
ventas = df["Ventas"]

# Graficar Pie Chart ordenado
plt.figure(figsize=(8, 8))
plt.pie(ventas, labels=marcas, autopct="%1.1f%%", startangle=180, colors=["red", "blue", "green", "purple", "orange", "gray"])

# Título
plt.title("Participación de Mercado de Marcas de Autos (Ordenado)")
plt.show()

# %% [markdown]
# Histogramas

# %% [markdown]
# Frecuencia Absoluta

# %%
# Datos simulados: tiempos de respuesta en milisegundos
tiempos_respuesta = np.random.normal(loc=200, scale=50, size=1000)  # Media=200ms, Desviación=50ms

# Crear el histograma
plt.figure(figsize=(10, 5))
plt.hist(tiempos_respuesta, bins=50, color='skyblue', edgecolor='black', alpha=0.7)

# Añadir etiquetas y título
plt.xlabel("Tiempo de Respuesta (ms)")
plt.ylabel("Frecuencia")
plt.title("Distribución de Tiempos de Respuesta del Servidor")
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Mostrar el histograma
plt.show()

# %%
tiempos_respuesta

# %%
# Datos simulados: tiempos de respuesta en milisegundos
tiempos_respuesta = np.random.normal(loc=200, scale=50, size=1000)  # Media=200ms, Desviación=50ms

# Crear el histograma
plt.figure(figsize=(10, 5))
##### density true
"""
Cuando usas density=True en un histograma en matplotlib o seaborn,
estás pidiendo que el histograma sea normalizado, de modo que el área total
del histograma sea igual a 1, convirtiéndolo en una función de
densidad de probabilidad.
"""

plt.hist(tiempos_respuesta, bins=50, color='skyblue', edgecolor='black', alpha=0.7, density=True)

# Añadir etiquetas y título
plt.xlabel("Tiempo de Respuesta (ms)")
plt.ylabel("Frecuencia")
plt.title("Distribución de Tiempos de Respuesta del Servidor")
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Mostrar el histograma
plt.show()

# %% [markdown]
# Gráfico de puntos o de dispersion (scatterplot)

# %%
np.random.seed(42)

# Simular datos de horas de estudio y calificación en examen
horas_estudio = np.random.randint(1, 11, 100)  # Horas de estudio (1 a 10 horas)
calificaciones = horas_estudio * 10 + np.random.randint(0, 5, 100)  # Relación lineal + ruido

# %%
calificaciones
# Out:
# array([ 73,  41,  80,  54,  72, 103,  32,  72,  80,  52,  44,  82,  80,
#         34,  61,  52,  20,  81,  61,  23,  54,  12, 100,  63,  94,  13,
#        104,  34,  72,  44,  93,  34,  52,  32,  73,  51,  91,  74,  20,
#         44,  93,  23, 103,  93, 103,  52,  21,  43,  70,  80,  30,  10,
#         42,  20,  83,  44,  20,  62,  62, 100,  44,  60,  22, 101,  23,
#        102,  40,  83,  70,  90,  81,  53,  23,  51,  82, 100,  94,  90,
#         10,  92,  70,  91,  81,  13,  84,  80,  30,  12,  81,  34,  33,
#         11,  53, 102,  72, 100,  94,  73,  91,  82])

# %%
horas_estudio
# Out:
# array([ 7,  4,  8,  5,  7, 10,  3,  7,  8,  5,  4,  8,  8,  3,  6,  5,  2,
#         8,  6,  2,  5,  1, 10,  6,  9,  1, 10,  3,  7,  4,  9,  3,  5,  3,
#         7,  5,  9,  7,  2,  4,  9,  2, 10,  9, 10,  5,  2,  4,  7,  8,  3,
#         1,  4,  2,  8,  4,  2,  6,  6, 10,  4,  6,  2, 10,  2, 10,  4,  8,
#         7,  9,  8,  5,  2,  5,  8, 10,  9,  9,  1,  9,  7,  9,  8,  1,  8,
#         8,  3,  1,  8,  3,  3,  1,  5, 10,  7, 10,  9,  7,  9,  8])

# %%
df = pd.DataFrame({"horas_estudio": horas_estudio, "calificaciones": calificaciones})

# %%
# lo hacemos con seaborn

# import seaborn as sns

# Crear el scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(horas_estudio, calificaciones, color='skyblue', alpha=0.6)

# Agregar título y etiquetas
plt.title("Relación entre Horas de Estudio y Calificación en Examen", fontsize=14, fontweight="bold")
plt.xlabel("Horas de Estudio", fontsize=12)
plt.ylabel("Calificación en Examen", fontsize=12)

# Añadir una línea de tendencia (regresión lineal)
# sns.regplot(x=horas_estudio, y=calificaciones, scatter=False, color="orange", line_kws={"linewidth": 2})

# Mostrar el gráfico
plt.grid(True, linestyle="--", alpha=0.7)

# Añadir una línea de tendencia (Regresión Lineal)
# sns.regplot(x=horas_estudio, y=calificaciones, scatter=False, color="orange", line_kws={"linewidth": 2, "label": "Tendencia"})


plt.show()

# %% [markdown]
# Boxplot

# %% [markdown]
# Ayuda a visualizar la distribución de datos y detectar **outliers.**

# %% [markdown]
# Caja (box):
#
# La caja se dibuja entre el primer cuartil (Q1) y el tercer cuartil (Q3). El primer cuartil es el valor que divide el 25% inferior de los datos, y el tercer cuartil divide el 25% superior. Es decir, el 50% de los datos están dentro de la caja. La longitud de la caja es la rango intercuartílico (IQR), que es la diferencia entre Q3 y Q1. Esto representa la dispersión de la mitad central de los datos. Línea en el medio de la caja (mediana):
#
# La línea dentro de la caja es la mediana de los datos (también conocida como el segundo cuartil, Q2). La mediana divide a los datos en dos partes iguales, es el valor central cuando los datos están ordenados. Bigotes (whiskers):
#
# Los bigotes se extienden desde los cuartiles hasta el valor máximo y el valor mínimo dentro de un rango aceptable. Este rango es generalmente 1.5 veces el rango intercuartílico (IQR). Cualquier valor fuera de este rango se considera un outlier (valor atípico). Outliers:
#
# Son los puntos que se encuentran fuera de los bigotes (más allá de 1.5 veces el IQR). Estos valores pueden indicar errores de medición o variaciones inusuales en los datos.

# %%
# Datos simulados: alturas de personas en cm
alturas = np.random.normal(loc=170, scale=10, size=1000)  # Media=170 cm, Desviación=10 cm

# %%
alturas

# %%
# Crear el Boxplot
plt.figure(figsize=(8, 6))
plt.boxplot(alturas, vert=False, patch_artist=True,
            boxprops=dict(facecolor='skyblue', color='black'),
            whiskerprops=dict(color='black', linewidth=1.5),
            flierprops=dict(marker='o', color='red', markersize=5))

# Añadir etiquetas y título
plt.xlabel('Altura (cm)')
plt.title('Boxplot de Alturas de Personas')

plt.grid(True, axis='x', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# Seaborn
#
# Seaborn es una biblioteca de visualización de datos basada en matplotlib que facilita la creación de gráficos atractivos y estadísticamente informativos con menos código. Proporciona una interfaz más sencilla y estilos predefinidos que hacen que los gráficos sean más fáciles de entender y más visualmente agradables.

# %%
import seaborn as sns

# %% [markdown]
# Facegrid

# %%
# cargamos el dataset
propinas = sns.load_dataset("tips")

# %%
propinas.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
propinas.shape
# Out:
# (244, 7)

# %%
grafico = sns.FacetGrid(data=propinas, col="time", row="sex")

# %%
grafico = sns.FacetGrid(data=propinas, col="time", row="sex")
# graficamos el tip en funcion del total_bill
grafico.map(sns.scatterplot, "total_bill", "tip")

# %%
# creamos un facetgrid basico
# grafico.add_legend()
grafico = sns.FacetGrid(propinas, col="sex", row="time", hue="smoker", palette="rocket")
# con map aplicamos un grafico de dispersion a cada subgrupo
grafico.map(sns.scatterplot, "total_bill", "tip")
grafico.add_legend()
grafico.set_titles(col_template="{col_name} (SEXO)", row_template="{row_name} - (Horario)")
plt.show()
