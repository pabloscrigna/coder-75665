# %% [markdown]
# <img src="https://user-images.githubusercontent.com/7065401/75165824-badf4680-5701-11ea-9c5b-5475b0a33abf.png"
#     style="width:300px; float: right; margin: 0 40px 40px 40px;"></img>
#
#
# # Pandas - `DataFrame`s
#
#
# Probablemente la estructura de datos más importante de pandas sea el "DataFrame". Es una estructura tabular estrechamente integrada con "Series".

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %%
# importamos las librerias
import numpy as np
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.2'

# %% [markdown]
# Continuamos con el analisis de los paises del G7.
#
# Por lo general los DataFrame se crean obteniando los datos de una base de datos, o de un csv.

# %%
df = pd.DataFrame({
    'Poblacion': [35.467, 63.951, 80.94 , 60.665, 127.061, 64.511, 318.523],
    'PBI': [
        1785387,
        2833687,
        3874437,
        2167744,
        4602367,
        2950039,
        17348075
    ],
    'Superficie': [
        9984670,
        640679,
        357114,
        301336,
        377930,
        242495,
        9525067
    ],
    'HDI': [
        0.913,
        0.888,
        0.916,
        0.873,
        0.891,
        0.907,
        0.915
    ],
    'Continente': [
        'America',
        'Europa',
        'Europa',
        'Europa',
        'Asia',
        'Europe',
        'America',
    ]
}, columns=['Poblacion', 'PBI', 'Superficie', 'HDI', 'Continente'])

# %%
df
# Out:
#    Poblacion       PBI  Superficie    HDI Continente
# 0     35.467   1785387     9984670  0.913    America
# 1     63.951   2833687      640679  0.888     Europa
# 2     80.940   3874437      357114  0.916     Europa
# 3     60.665   2167744      301336  0.873     Europa
# 4    127.061   4602367      377930  0.891       Asia
# 5     64.511   2950039      242495  0.907     Europe
# 6    318.523  17348075     9525067  0.915    America

# %% [markdown]
# Los DataFrames también tienen índices. Como se puede ver en la "tabla" anterior, pandas ha asignado automáticamente un índice numérico autoincremental a cada "fila" en nuestro DataFrame. En nuestro caso, sabemos que cada fila representa un país, así que simplemente reasignaremos el índice:

# %%
# Setear los indicies
df.index = [
    'Canada',
    'Francia',
    'Alemania',
    'Italia',
    'Japon',
    'Reino Unido',
    'Estados Unidos',
]

# %%
df
# Out:
#                 Poblacion       PBI  Superficie    HDI Continente
# Canada             35.467   1785387     9984670  0.913    America
# Francia            63.951   2833687      640679  0.888     Europa
# Alemania           80.940   3874437      357114  0.916     Europa
# Italia             60.665   2167744      301336  0.873     Europa
# Japon             127.061   4602367      377930  0.891       Asia
# Reino Unido        64.511   2950039      242495  0.907     Europe
# Estados Unidos    318.523  17348075     9525067  0.915    America

# %%
# ver las columnas del DataFrame
df.columns
# Out:
# Index(['Poblacion', 'PBI', 'Superficie', 'HDI', 'Continente'], dtype='object')

# %%
for columna in df.columns:
  print(columna)
# Out:
# Poblacion
# PBI
# Superficie
# HDI
# Continente

# %%
# ver los indices
df.index
# Out:
# Index(['Canada', 'Francia', 'Alemania', 'Italia', 'Japon', 'Reino Unido',
#        'Estados Unidos'],
#       dtype='object')

# %%
# informacion sobre la estructura del dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, Canada to Estados Unidos
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Poblacion   7 non-null      float64
#  1   PBI         7 non-null      int64
#  2   Superficie  7 non-null      int64
#  3   HDI         7 non-null      float64
#  4   Continente  7 non-null      object
# dtypes: float64(2), int64(2), object(1)
# memory usage: 636.0+ bytes

# %%
# ver la cantidad de filas y columnas
df.shape
# Out:
# (7, 5)

# %%
# numero total de elementos el producto fila x columna
df.size
# Out:
# 35

# %%
# informacion numerica
df.describe()
# Out:
#         Poblacion           PBI    Superficie       HDI
# count    7.000000  7.000000e+00  7.000000e+00  7.000000
# mean   107.302571  5.080248e+06  3.061327e+06  0.900429
# std     97.249970  5.494020e+06  4.576187e+06  0.016592
# min     35.467000  1.785387e+06  2.424950e+05  0.873000
# 25%     62.308000  2.500716e+06  3.292250e+05  0.889500
# 50%     64.511000  2.950039e+06  3.779300e+05  0.907000
# 75%    104.000500  4.238402e+06  5.082873e+06  0.914000
# max    318.523000  1.734808e+07  9.984670e+06  0.916000

# %%
# ver los tipos de datos
df.dtypes
# Out:
# Poblacion     float64
# PBI             int64
# Superficie      int64
# HDI           float64
# Continente     object
# dtype: object

# %%
df.dtypes.value_counts()
# Out:
# float64    2
# int64      2
# object     1
# Name: count, dtype: int64

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Indexacion, Seleccion y Slicing
#
# Podemos seleccionar una columna de manera individual utilizando indexacion. La columna es representada como una Serie.

# %%
df
# Out:
#                 Poblacion       PBI  Superficie    HDI Continente
# Canada             35.467   1785387     9984670  0.913    America
# Francia            63.951   2833687      640679  0.888     Europa
# Alemania           80.940   3874437      357114  0.916     Europa
# Italia             60.665   2167744      301336  0.873     Europa
# Japon             127.061   4602367      377930  0.891       Asia
# Reino Unido        64.511   2950039      242495  0.907     Europe
# Estados Unidos    318.523  17348075     9525067  0.915    America

# %%
# seleccion como serie
poblacion = df['Poblacion']
poblacion
# Out:
# Canada             35.467
# Francia            63.951
# Alemania           80.940
# Italia             60.665
# Japon             127.061
# Reino Unido        64.511
# Estados Unidos    318.523
# Name: Poblacion, dtype: float64

# %% [markdown]
# El nombre de la serie, es el nombre de la columna

# %%
# seleccion como df
poblacion_df = df['Poblacion'].to_frame()
poblacion_df
# Out:
#                 Poblacion
# Canada             35.467
# Francia            63.951
# Alemania           80.940
# Italia             60.665
# Japon             127.061
# Reino Unido        64.511
# Estados Unidos    318.523

# %% [markdown]
# Tambien es posible seleccionar multiples columnas

# %%
# seleccion de dos columnas
df_nuevo = df[['Poblacion', 'PBI']]
df_nuevo
# Out:
#                 Poblacion       PBI
# Canada             35.467   1785387
# Francia            63.951   2833687
# Alemania           80.940   3874437
# Italia             60.665   2167744
# Japon             127.061   4602367
# Reino Unido        64.511   2950039
# Estados Unidos    318.523  17348075

# %% [markdown]
# En este caso, el resultado es otro DataFrame

# %% [markdown]
# La seleccion de filas, funciona mejor con loc y con iloc

# %%
df.loc['Italia']
# Out:
# Poblacion      60.665
# PBI           2167744
# Superficie     301336
# HDI             0.873
# Continente     Europa
# Name: Italia, dtype: object

# %%
df.loc['Francia':'Italia']
# Out:
#           Poblacion      PBI  Superficie    HDI Continente
# Francia      63.951  2833687      640679  0.888     Europa
# Alemania     80.940  3874437      357114  0.916     Europa
# Italia       60.665  2167744      301336  0.873     Europa

# %% [markdown]
# Tambien se pueden seleccinar que columna/s se quieren obtener

# %%
df.loc['Francia': 'Italia', 'Poblacion']
# Out:
# Francia     63.951
# Alemania    80.940
# Italia      60.665
# Name: Poblacion, dtype: float64

# %%
df.loc['Francia':'Italia', ['Poblacion', "PBI"]]
# Out:
#           Poblacion      PBI
# Francia      63.951  2833687
# Alemania     80.940  3874437
# Italia       60.665  2167744

# %% [markdown]
# Recordar: iloc funciona con los indices numericos

# %%
df
# Out:
#                 Poblacion       PBI  Superficie    HDI Continente
# Canada             35.467   1785387     9984670  0.913    America
# Francia            63.951   2833687      640679  0.888     Europa
# Alemania           80.940   3874437      357114  0.916     Europa
# Italia             60.665   2167744      301336  0.873     Europa
# Japon             127.061   4602367      377930  0.891       Asia
# Reino Unido        64.511   2950039      242495  0.907     Europe
# Estados Unidos    318.523  17348075     9525067  0.915    America

# %%
df.iloc[0]
# Out:
# Poblacion      35.467
# PBI           1785387
# Superficie    9984670
# HDI             0.913
# Continente    America
# Name: Canada, dtype: object

# %% [markdown]
# > **RECOMENDACION: Siempre usar `loc` and `iloc` especialmente en DataFrame con indices numericos.**

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Seleccion Condicional (arrays booleanos)
#
# Funciona igual que en las Series

# %%
df
# Out:
#                 Poblacion       PBI  Superficie    HDI Continente
# Canada             35.467   1785387     9984670  0.913    America
# Francia            63.951   2833687      640679  0.888     Europa
# Alemania           80.940   3874437      357114  0.916     Europa
# Italia             60.665   2167744      301336  0.873     Europa
# Japon             127.061   4602367      377930  0.891       Asia
# Reino Unido        64.511   2950039      242495  0.907     Europe
# Estados Unidos    318.523  17348075     9525067  0.915    America

# %%
df['Poblacion'] > 70
# Out:
# Canada            False
# Francia           False
# Alemania           True
# Italia            False
# Japon              True
# Reino Unido       False
# Estados Unidos     True
# Name: Poblacion, dtype: bool

# %%
df.loc[df['Poblacion'] > 70]
# Out:
#                 Poblacion       PBI  Superficie    HDI Continente
# Alemania           80.940   3874437      357114  0.916     Europa
# Japon             127.061   4602367      377930  0.891       Asia
# Estados Unidos    318.523  17348075     9525067  0.915    America

# %%
df.loc[df['Poblacion'] > 70, ["PBI", "HDI"]]
# Out:
#                      PBI    HDI
# Alemania         3874437  0.916
# Japon            4602367  0.891
# Estados Unidos  17348075  0.915

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Eliminando Filas y Columnas

# %%
df
# Out:
#                 Poblacion       PBI  Superficie    HDI Continente
# Canada             35.467   1785387     9984670  0.913    America
# Francia            63.951   2833687      640679  0.888     Europa
# Alemania           80.940   3874437      357114  0.916     Europa
# Italia             60.665   2167744      301336  0.873     Europa
# Japon             127.061   4602367      377930  0.891       Asia
# Reino Unido        64.511   2950039      242495  0.907     Europe
# Estados Unidos    318.523  17348075     9525067  0.915    America

# %%
#filas
df.drop('Canada')
# Out:
#                 Poblacion       PBI  Superficie    HDI Continente
# Francia            63.951   2833687      640679  0.888     Europa
# Alemania           80.940   3874437      357114  0.916     Europa
# Italia             60.665   2167744      301336  0.873     Europa
# Japon             127.061   4602367      377930  0.891       Asia
# Reino Unido        64.511   2950039      242495  0.907     Europe
# Estados Unidos    318.523  17348075     9525067  0.915    America

# %%
# mas de una fila
df.drop(['Canada', 'Italia'])
# Out:
#                 Poblacion       PBI  Superficie    HDI Continente
# Francia            63.951   2833687      640679  0.888     Europa
# Alemania           80.940   3874437      357114  0.916     Europa
# Japon             127.061   4602367      377930  0.891       Asia
# Reino Unido        64.511   2950039      242495  0.907     Europe
# Estados Unidos    318.523  17348075     9525067  0.915    America

# %%
# columnas
df.drop(columns=['Poblacion', 'HDI'])
# Out:
#                      PBI  Superficie Continente
# Canada           1785387     9984670    America
# Francia          2833687      640679     Europa
# Alemania         3874437      357114     Europa
# Italia           2167744      301336     Europa
# Japon            4602367      377930       Asia
# Reino Unido      2950039      242495     Europe
# Estados Unidos  17348075     9525067    America

# %% [markdown]
# > axis=0 Accion en filas<br>
# > axis= 1 Accion en columnas

# %%
df.drop(['Poblacion'], axis=1)
# Out:
#                      PBI  Superficie    HDI Continente
# Canada           1785387     9984670  0.913    America
# Francia          2833687      640679  0.888     Europa
# Alemania         3874437      357114  0.916     Europa
# Italia           2167744      301336  0.873     Europa
# Japon            4602367      377930  0.891       Asia
# Reino Unido      2950039      242495  0.907     Europe
# Estados Unidos  17348075     9525067  0.915    America

# %% [markdown]
# Los metodos anteriores retornan un nuevo DataFrame. Para modificar el mismo DataFrame se puede utilizar el atributo inplace

# %%
# ejemplo inplace
pasajeros_dict = {
    'Nombre': ['Ana', 'Luis', 'Carlos'],
    'Edad': [25, 30, 22],
    'Ciudad': ['Madrid', 'Barcelona', 'Sevilla']
}
pasajeros = pd.DataFrame(pasajeros_dict)

# %%
pasajeros.drop('Edad', axis=1, inplace=True)

# %%
pasajeros
# Out:
#    Nombre     Ciudad
# 0     Ana     Madrid
# 1    Luis  Barcelona
# 2  Carlos    Sevilla

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Modificando los DataFrames
#
# Se pueden agregar columnas o reemplazar valores de las columnas

# %% [markdown]
# ### Agregando una nueva columna

# %%
idiomas = pd.Series(
    ['Frances', 'Aleman', 'Italiano'],
    index=['Francia', 'Alemania', 'Italia'],
    name='Idiomas'
)

# %%
idiomas

# %%
# agregamos la serie idiomas al df
df['Idiomas'] = idiomas

# %%
df
# Out:
#                 Poblacion       PBI  Superficie    HDI Continente   Idiomas
# Canada             35.467   1785387     9984670  0.913    America       NaN
# Francia            63.951   2833687      640679  0.888     Europa   Frances
# Alemania           80.940   3874437      357114  0.916     Europa    Aleman
# Italia             60.665   2167744      301336  0.873     Europa  Italiano
# Japon             127.061   4602367      377930  0.891       Asia       NaN
# Reino Unido        64.511   2950039      242495  0.907     Europe       NaN
# Estados Unidos    318.523  17348075     9525067  0.915    America       NaN

# %% [markdown]
# ### Reemplazando valores de una columna

# %%
# reemplazar todos los valores
df['Idiomas'] = "Ingles"

# %%
df
# Out:
#                 Poblacion       PBI  Superficie    HDI Continente Idiomas
# Canada             35.467   1785387     9984670  0.913    America  Ingles
# Francia            63.951   2833687      640679  0.888     Europa  Ingles
# Alemania           80.940   3874437      357114  0.916     Europa  Ingles
# Italia             60.665   2167744      301336  0.873     Europa  Ingles
# Japon             127.061   4602367      377930  0.891       Asia  Ingles
# Reino Unido        64.511   2950039      242495  0.907     Europe  Ingles
# Estados Unidos    318.523  17348075     9525067  0.915    America  Ingles

# %%
df.rename(index=str.upper)
# Out:
#                 Poblacion       PBI  Superficie    HDI Continente Idiomas
# CANADA             35.467   1785387     9984670  0.913    America  Ingles
# FRANCIA            63.951   2833687      640679  0.888     Europa  Ingles
# ALEMANIA           80.940   3874437      357114  0.916     Europa  Ingles
# ITALIA             60.665   2167744      301336  0.873     Europa  Ingles
# JAPON             127.061   4602367      377930  0.891       Asia  Ingles
# REINO UNIDO        64.511   2950039      242495  0.907     Europe  Ingles
# ESTADOS UNIDOS    318.523  17348075     9525067  0.915    America  Ingles

# %% [markdown]
# ### Agregando valores

# %%
# Series nuevas
# pd.append --> obsoleto de la version 1.3 y eliminado de pandas 2.0
# pd.concat
pd.concat([df, pd.Series({"Canada"}, name='Columna')])
# Out:
#                 Poblacion         PBI  Superficie    HDI Continente Idiomas  \
# Canada             35.467   1785387.0   9984670.0  0.913    America  Ingles
# Francia            63.951   2833687.0    640679.0  0.888     Europa  Ingles
# Alemania           80.940   3874437.0    357114.0  0.916     Europa  Ingles
# Italia             60.665   2167744.0    301336.0  0.873     Europa  Ingles
# Japon             127.061   4602367.0    377930.0  0.891       Asia  Ingles
# Reino Unido        64.511   2950039.0    242495.0  0.907     Europe  Ingles
# Estados Unidos    318.523  17348075.0   9525067.0  0.915    America  Ingles
# Poblacion             NaN         NaN         NaN    NaN        NaN     NaN
# PBI                   NaN         NaN         NaN    NaN        NaN     NaN
#
#                 China
# Canada            NaN
# Francia           NaN
# Alemania          NaN
# Italia            NaN
# Japon             NaN
# Reino Unido       NaN
# Estados Unidos    NaN
# Poblacion         3.0
# PBI               5.0

# %% [markdown]
# ### Creando nuevas columnas a partir de otras columnas

# %% [markdown]
# Podemos calcular el producto bruto per capita, haciendo la siguiente cuenta: `PBI / Poblacion`.

# %%
# volver a correr el data frame
df
# Out:
#                 Poblacion       PBI  Superficie    HDI Continente Idiomas
# Canada             35.467   1785387     9984670  0.913    America  Ingles
# Francia            63.951   2833687      640679  0.888     Europa  Ingles
# Alemania           80.940   3874437      357114  0.916     Europa  Ingles
# Italia             60.665   2167744      301336  0.873     Europa  Ingles
# Japon             127.061   4602367      377930  0.891       Asia  Ingles
# Reino Unido        64.511   2950039      242495  0.907     Europe  Ingles
# Estados Unidos    318.523  17348075     9525067  0.915    America  Ingles

# %%
# Crear la columna Poblacion / PBI    pbi per capita

df['PBI per capita'] = df['PBI'] / df['Poblacion']
df
# Out:
#                 Poblacion       PBI  Superficie    HDI Continente Idiomas  \
# Canada             35.467   1785387     9984670  0.913    America  Ingles
# Francia            63.951   2833687      640679  0.888     Europa  Ingles
# Alemania           80.940   3874437      357114  0.916     Europa  Ingles
# Italia             60.665   2167744      301336  0.873     Europa  Ingles
# Japon             127.061   4602367      377930  0.891       Asia  Ingles
# Reino Unido        64.511   2950039      242495  0.907     Europe  Ingles
# Estados Unidos    318.523  17348075     9525067  0.915    America  Ingles
#
#                 PBI per capita
# Canada            50339.385908
# Francia           44310.284437
# Alemania          47868.013343
# Italia            35733.025633
# Japon             36221.712406
# Reino Unido       45729.239975
# Estados Unidos    54464.120330

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Estadisticas

# %%
df.head()
# Out:
#           Poblacion      PBI  Superficie    HDI Continente Idiomas  \
# Canada       35.467  1785387     9984670  0.913    America  Ingles
# Francia      63.951  2833687      640679  0.888     Europa  Ingles
# Alemania     80.940  3874437      357114  0.916     Europa  Ingles
# Italia       60.665  2167744      301336  0.873     Europa  Ingles
# Japon       127.061  4602367      377930  0.891       Asia  Ingles
#
#           PBI per capita
# Canada      50339.385908
# Francia     44310.284437
# Alemania    47868.013343
# Italia      35733.025633
# Japon       36221.712406

# %%
df.tail()
# Out:
#                 Poblacion       PBI  Superficie    HDI Continente Idiomas  \
# Alemania           80.940   3874437      357114  0.916     Europa  Ingles
# Italia             60.665   2167744      301336  0.873     Europa  Ingles
# Japon             127.061   4602367      377930  0.891       Asia  Ingles
# Reino Unido        64.511   2950039      242495  0.907     Europe  Ingles
# Estados Unidos    318.523  17348075     9525067  0.915    America  Ingles
#
#                 PBI per capita
# Alemania          47868.013343
# Italia            35733.025633
# Japon             36221.712406
# Reino Unido       45729.239975
# Estados Unidos    54464.120330

# %%
df.describe()
# Out:
#         Poblacion           PBI    Superficie       HDI  PBI per capita
# count    7.000000  7.000000e+00  7.000000e+00  7.000000        7.000000
# mean   107.302571  5.080248e+06  3.061327e+06  0.900429    44952.254576
# std     97.249970  5.494020e+06  4.576187e+06  0.016592     6954.983875
# min     35.467000  1.785387e+06  2.424950e+05  0.873000    35733.025633
# 25%     62.308000  2.500716e+06  3.292250e+05  0.889500    40265.998421
# 50%     64.511000  2.950039e+06  3.779300e+05  0.907000    45729.239975
# 75%    104.000500  4.238402e+06  5.082873e+06  0.914000    49103.699626
# max    318.523000  1.734808e+07  9.984670e+06  0.916000    54464.120330

# %%
poblacion = df['Poblacion']

# %%
poblacion.max()
# Out:
# 318.523

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %%
# datetime

data = {'Fecha': ['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04', '2024-01-05'],
        'Valor': [10, 20, 30, 40, 50]}
df = pd.DataFrame(data)
df
# Out:
#         Fecha  Valor
# 0  2024-01-01     10
# 1  2024-01-02     20
# 2  2024-01-03     30
# 3  2024-01-04     40
# 4  2024-01-05     50

# %%
df.dtypes
# Out:
# Fecha    object
# Valor     int64
# dtype: object

# %%
df['Fecha'] = pd.to_datetime(df['Fecha'])

# %%
df
# Out:
#        Fecha  Valor
# 0 2024-01-01     10
# 1 2024-01-02     20
# 2 2024-01-03     30
# 3 2024-01-04     40
# 4 2024-01-05     50

# %%
df.dtypes
# Out:
# Fecha    datetime64[ns]
# Valor             int64
# dtype: object
