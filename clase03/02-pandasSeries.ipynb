# %% [markdown]
# <img src="https://user-images.githubusercontent.com/7065401/75165824-badf4680-5701-11ea-9c5b-5475b0a33abf.png"
#     style="width:300px; float: right; margin: 0 40px 40px 40px;"></img>
#
#
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %% [markdown]
# Es una librería de Python diseñada para facilitar el manejo y análisis de datos. Construida sobre NumPy, Pandas extiende sus capacidades, proporcionando estructuras de datos y funciones avanzadas que permiten una manipulación más flexible y eficiente de datos tabulares y de series temporales.[Documentacion](https://pypi.org/project/pandas/)

# %%
# importamos la libreria
import pandas as pd
import numpy as np

# %% [markdown]
# ### Release

# %%
pd.__version__
# Out:
# '2.2.2'

# %% [markdown]
# ## Estructuras de Datos

# %% [markdown]
# Dos estrucutras de datos principales:
#
# * Series
# * DataFrame

# %% [markdown]
# ## Pandas - Series
#
# Vamos a analizar el G7, el cual es un partido político formado por Canadá, Francia, Alemania, Italia, Japón, Reino Unido y Estados Unidos. Comenzaremos analizando la población y para ello usaremos un objeto `pandas.Series`.

# %%
# En millones
g7_poblacion = pd.Series([35.467, 63.951, 80.940, 60.665, 127.061, 64.511, 318.523])

# %%
g7_poblacion
# Out:
# 0     35.467
# 1     63.951
# 2     80.940
# 3     60.665
# 4    127.061
# 5     64.511
# 6    318.523
# dtype: float64

# %% [markdown]
# La Serie puede tener un nombre, para documentar mejor el propósito de la Serie.

# %%
g7_poblacion.name = "G7 poblacion en millones"

# %%
g7_poblacion
# Out:
# 0     35.467
# 1     63.951
# 2     80.940
# 3     60.665
# 4    127.061
# 5     64.511
# 6    318.523
# Name: G7 poblacion en millones, dtype: float64

# %% [markdown]
# Son muy parecidas a los arrays en NumPy.

# %%
# ver el tipo de dato de una serie
g7_poblacion.dtype
# Out:
# dtype('float64')

# %%
# Ver los valores de una serie
g7_poblacion.values
# Out:
# array([ 35.467,  63.951,  80.94 ,  60.665, 127.061,  64.511, 318.523])

# %% [markdown]
# De hecho se almacenan en numpy arrays

# %%
# ver el tipo de dato de los valores
type(g7_poblacion.values)
# Out:
# numpy.ndarray

# %% [markdown]
# Si bien son parecidas a las listas en Python o a los Arrays de NumPy, son mas parecidas a los diccionarios de Python.

# %%
g7_poblacion
# Out:
# 0     35.467
# 1     63.951
# 2     80.940
# 3     60.665
# 4    127.061
# 5     64.511
# 6    318.523
# Name: G7 poblacion en millones, dtype: float64

# %%
g7_poblacion[0]
# Out:
# 35.467

# %%
g7_poblacion[1]
# Out:
# 63.951

# %%
g7_poblacion.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %% [markdown]
# A diferencia de las listas en Python, podemos definir un valor a cada indice

# %%
g7_poblacion.index = [
    'Canada',
    'Francia',
    'Alemania',
    'Italia',
    'Japon',
    'Reino Unido',
    'Estados Unidos',
]

# %%
g7_poblacion
# Out:
# Canada             35.467
# Francia            63.951
# Alemania           80.940
# Italia             60.665
# Japon             127.061
# Reino Unido        64.511
# Estados Unidos    318.523
# Name: G7 poblacion en millones, dtype: float64

# %%
g7_poblacion['Canada']
# Out:
# 35.467

# %%
g7_poblacion['Francia']
# Out:
# 63.951

# %% [markdown]
# A diferencia de los diccionarios en Python, las series son estructuras de datos ordenadas.

# %% [markdown]
# Creacion de series I

# %%
# Creamos la serie asignando los indices y los valores
nueva_serie = pd.Series({
    'Canada': 35.467,
    'Francia': 63.951,
    'Alemania': 80.940,
    'Italia': 60.665,
    'Japon': 127.061,
    'Reino Unido': 64.511,
    'Estados Unidos': 318.523,
},name="g7 poblacion en millones")

# %%
nueva_serie
# Out:
# Canada             35.467
# Francia            63.951
# Alemania           80.940
# Italia             60.665
# Japon             127.061
# Reino Unido        64.511
# Estados Unidos    318.523
# Name: g7 poblacion en millones, dtype: float64

# %% [markdown]
# Creacion de Series II

# %%
nueva_2 = pd.Series([35.467, 63.951, 80.940, 60.665, 127.061, 64.511, 318.523],index=[
    'Canada',
    'Francia',
    'Alemania',
    'Italia',
    'Japon',
    'Reino Unido',
    'Estados Unidos',
], name="G7 poblacion")

# %%
nueva_2
# Out:
# Canada             35.467
# Francia            63.951
# Alemania           80.940
# Italia             60.665
# Japon             127.061
# Reino Unido        64.511
# Estados Unidos    318.523
# Name: G7 poblacion, dtype: float64

# %% [markdown]
# Tambien se pueden crear series a partir de otras series, especificando los indices.

# %%
g7_poblacion
# Out:
# Canada             35.467
# Francia            63.951
# Alemania           80.940
# Italia             60.665
# Japon             127.061
# Reino Unido        64.511
# Estados Unidos    318.523
# Name: G7 poblacion en millones, dtype: float64

# %%
nueva_s = pd.Series(g7_poblacion, index=['Canada', 'Francia', 'Alemania'])
nueva_s
# Out:
# Canada      35.467
# Francia     63.951
# Alemania    80.940
# Name: G7 poblacion en millones, dtype: float64

# %%
nueva_s.name = "G reducido"
nueva_s
# Out:
# Canada      35.467
# Francia     63.951
# Alemania    80.940
# Name: G reducido, dtype: float64

# %% [markdown]
# ## Indexacion

# %% [markdown]
# La indexacion funciona de manera similar a las listas y los diccionarios.
# Se usa el indice del elemento a buscar:

# %%
g7_poblacion
# Out:
# Canada             35.467
# Francia            63.951
# Alemania           80.940
# Italia             60.665
# Japon             127.061
# Reino Unido        64.511
# Estados Unidos    318.523
# Name: G7 poblacion en millones, dtype: float64

# %%
g7_poblacion['Canada']
# Out:
# 35.467

# %% [markdown]
# Con el atributo iloc accedemos a las posiciones con indices numericos:

# %%
g7_poblacion.iloc[0]
# Out:
# 35.467

# %%
# otro ejemplo
g7_poblacion.iloc[-1]
# Out:
# 318.523

# %% [markdown]
# Tambien es posible visualizar mas de un elemento a la vez (multiples indices)

# %%
g7_poblacion[['Japon', 'Alemania']]
# Out:
# Japon       127.061
# Alemania     80.940
# Name: G7 poblacion en millones, dtype: float64

# %% [markdown]
# El resultado es una nueva Serie.

# %%
g7_poblacion.iloc[[0, 3]]
# Out:
# Canada    35.467
# Italia    60.665
# Name: G7 poblacion en millones, dtype: float64

# %% [markdown]
# Slicing es soportado por las Series. A diferencia de las listas, el limite superior, se incluye en el resultado

# %%
g7_poblacion['Canada': 'Italia']
# Out:
# Canada      35.467
# Francia     63.951
# Alemania    80.940
# Italia      60.665
# Name: G7 poblacion en millones, dtype: float64

# %% [markdown]
# ## Seleccion condicional

# %%
g7_poblacion
# Out:
# Canada             35.467
# Francia            63.951
# Alemania           80.940
# Italia             60.665
# Japon             127.061
# Reino Unido        64.511
# Estados Unidos    318.523
# Name: G7 poblacion en millones, dtype: float64

# %%
g7_poblacion > 70
# Out:
# Canada            False
# Francia           False
# Alemania           True
# Italia            False
# Japon              True
# Reino Unido       False
# Estados Unidos     True
# Name: G7 poblacion en millones, dtype: bool

# %%
g7_mayor70 = g7_poblacion[g7_poblacion>70]

# %%
g7_mayor70
# Out:
# Alemania           80.940
# Japon             127.061
# Estados Unidos    318.523
# Name: G7 poblacion en millones, dtype: float64

# %%
g7_poblacion.mean()
# Out:
# 107.30257142857144

# %%
g7_mayor_mean = g7_poblacion[g7_poblacion>g7_poblacion.mean()]

# %%
g7_mayor_mean
# Out:
# Japon             127.061
# Estados Unidos    318.523
# Name: G7 poblacion en millones, dtype: float64

# %% [markdown]
# ## Operaciones matematicas

# %%
g7_poblacion
# Out:
# Canada             35.467
# Francia            63.951
# Alemania           80.940
# Italia             60.665
# Japon             127.061
# Reino Unido        64.511
# Estados Unidos    318.523
# Name: G7 poblacion en millones, dtype: float64

# %%
g7_poblacion * 1_000_000
# Out:
# Canada             35467000.0
# Francia            63951000.0
# Alemania           80940000.0
# Italia             60665000.0
# Japon             127061000.0
# Reino Unido        64511000.0
# Estados Unidos    318523000.0
# Name: G7 poblacion en millones, dtype: float64

# %%
np.log(g7_poblacion)
# Out:
# Canada            3.568603
# Francia           4.158117
# Alemania          4.393708
# Italia            4.105367
# Japon             4.844667
# Reino Unido       4.166836
# Estados Unidos    5.763695
# Name: G7 poblacion en millones, dtype: float64

# %% [markdown]
# ## Modificando la serie

# %%
g7_poblacion
# Out:
# Canada             35.467
# Francia            63.951
# Alemania           80.940
# Italia             60.665
# Japon             127.061
# Reino Unido        64.511
# Estados Unidos    318.523
# Name: G7 poblacion en millones, dtype: float64

# %%
g7_poblacion['Argentina'] = 45

# %%
g7_poblacion
# Out:
# Canada             35.467
# Francia            63.951
# Alemania           80.940
# Italia             60.665
# Japon             127.061
# Reino Unido        64.511
# Estados Unidos    318.523
# Argentina          45.000
# Name: G7 poblacion en millones, dtype: float64

# %%
g7_poblacion[g7_poblacion < g7_poblacion.mean()] = 99.9

# %%
g7_poblacion
# Out:
# Canada             99.900
# Francia            99.900
# Alemania           99.900
# Italia             99.900
# Japon             127.061
# Reino Unido        99.900
# Estados Unidos    318.523
# Argentina          99.900
# Name: G7 poblacion en millones, dtype: float64

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
